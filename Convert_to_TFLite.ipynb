# %%
# !python model_main_tf2.py --pipeline_config_path=ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config --model_dir=training --alsologtostderr
# Out:
# 2021-05-23 09:44:42.726674: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-23 09:44:44.555274: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-05-23 09:44:44.561596: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-23 09:44:44.562175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-05-23 09:44:44.562216: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !cp -r '/content/models/research/object_detection/export_tflite_ssd_graph.py' '/content/TF-2.x-Object-Detection'

# %%
# !tar -xf '/content/TF-2.x-Object-Detection/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'

# %%
ls
# Out:
#  Check_the_unique_key_for_class.py
#  exporter_main_v2.py
#  export_tflite_ssd_graph.py
#  generate_labelmap.py
#  generate_tfrecord.py
#  How_to_deploy_Object_Detection_If_No_Colab.ipynb
#  How_to_deploy_Object_Detection.ipynb
#  How_To_Train.ipynb
#  images/
#  inference_graph/
#  Install-TensorFlow-Python3.7.ps1
#  model_main_tf2.py
# 'Msvcp71.dll-And-Msvcr71.dll-files by harjot pawra.zip'
#  object_detection_tutorial.ipynb
#  sd.zip
#  ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/
#  ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz
#  test.record
#  training/
#  train.record
#  xml_to_csv.py

# %%
# !cp -r '/content/models/research/object_detection/export_tflite_graph_tf2.py' '/content/TF-2.x-Object-Detection'

# %%
# !python export_tflite_graph_tf2.py \
    --pipeline_config_path /content/TF-2.x-Object-Detection/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config \
    --trained_checkpoint_dir /content/TF-2.x-Object-Detection/training \
    --output_directory /content/TFLITE000
# Out:
# 2021-05-23 10:22:40.170341: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-23 10:22:41.812508: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-05-23 10:22:41.818108: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-23 10:22:41.818788: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-05-23 10:22:41.818829: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !tflite_convert \
    --graph_def_file=/content/TFLITE000/saved_model/saved_model.pb \
    --saved_model_dir=/content/TFLITE000/saved_model \
    --output_file=model000.tflite \
    --output_format=TFLITE \
    --input_arrays=normalized_input_image_tensor \
    --input_shapes=1,300,300,3 \
    --inference_type=FLOAT \
    --output_arrays="TFLite_Detection_PostProcess,TFLite_Detection_PostProcess:1,TFLite_Detection_PostProcess:2,TFLite_Detection_PostProcess:3" \
    --allow_custom_ops
# Out:
# 2021-05-23 10:23:48.759377: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-23 10:23:50.315213: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-05-23 10:23:50.320769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-23 10:23:50.321354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-05-23 10:23:50.321392: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !du -sh /content/TFLITE/saved_model/saved_model.pb
# Out:
# 12M	/content/TFLITE/saved_model/saved_model.pb
